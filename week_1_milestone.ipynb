# %%
# Crop Yield Prediction - Week 1 Milestone

## Objective
# Predict crop yields using features like Crop, State, Season, Rainfall, Fertilizer usage, and Area.

## Dataset
# - Sample of 5–10 rows loaded
# - Features:
#   - Crop (categorical)
#   - State (categorical)
#   - Season (categorical)
#   - Area, Production, Annual_Rainfall, Fertilizer, Pesticide (numeric)
#   - Yield (target variable)

## Data Preprocessing
# - Handled missing values (none in sample)
# - Encoded categorical columns: Crop, State, Season
# - Scaled numeric features

# ```python
# Sample preprocessing snippet
import pandas as pd
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv("week_1_dataset.csv", sep=',', encoding='utf-8-sig', quotechar='"')
print(df.columns) # Print column names to help diagnose KeyError
print(df['Crop'].dtype) # Print the data type of the 'Crop' column
print(df['Crop'].unique()) # Print unique values in the 'Crop' column
le = LabelEncoder()
df['Crop'] = le.fit_transform(df['Crop'])
df.head()
# Out:
# Index(['Crop,Crop_Year,Season,State,Area,Production,Annual_Rainfall,Fertilizer,Pesticide,Yield'], dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Crop'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
with open('week_1_dataset.csv', 'r') as f:
    for i in range(5): # Read and print the first 5 lines
        print(f.readline())
# Out:
# ﻿"Crop,Crop_Year,Season,State,Area,Production,Annual_Rainfall,Fertilizer,Pesticide,Yield"
#
# "Rice,2015,Whole Year,Karnataka,500,4200,1200,50,20,8.4"
#
# "Wheat,2015,Rabi,Maharashtra,600,5400,800,45,15,9.0"
#
# "Maize,2015,Kharif,Andhra Pradesh,400,3200,900,40,18,8.0"
#
# "Sugarcane,2015,Whole Year,Uttar Pradesh,300,3900,1100,55,25,13.0"

# %%
# Week 1: Data Loading & Preprocessing
from google.colab import files
uploaded = files.upload()


import pandas as pd
import numpy as np

# ✅ Change path to your actual file location
file_path = "crop_yield.csv"

# Load with safe encoding
df = pd.read_csv(file_path, encoding='utf-8-sig')

# ------------------------------
# 1. Inspect the dataset
# ------------------------------
print("Shape of dataset:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nFirst 5 rows:")
print(df.head())

# ------------------------------
# 2. Clean column names
# ------------------------------
df.columns = df.columns.str.strip()  # remove extra spaces
df.columns = df.columns.str.replace(" ", "_")  # replace spaces with underscores
df.columns = df.columns.str.lower()  # lowercase for uniformity

print("\nCleaned Columns:", df.columns.tolist())

# ------------------------------
# 3. Basic Info
# ------------------------------
print("\nData types:")
print(df.dtypes)

print("\nMissing values per column:")
print(df.isnull().sum())

# ------------------------------
# 4. Save cleaned dataset (for later weeks)
# ------------------------------
df.to_csv("data/cleaned_crop_dataset.csv", index=False, encoding="utf-8-sig")
print("\n✅ Cleaned dataset saved as 'cleaned_crop_dataset.csv'")
# Out:
#      <input type="file" id="files-dc9850d6-5c5e-4f20-8111-5de1b94383d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc9850d6-5c5e-4f20-8111-5de1b94383d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
